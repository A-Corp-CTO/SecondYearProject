# %%
import span_f1


import matplotlib.pyplot as plt
def learning_curve(golds, preds):
	scores = []
	for gold, pred in zip(golds, preds):
		scores.append(span_f1.getInstanceScores(gold, pred))
	return scores


size = [10, 20, 30, 40, 50, 60]
golds = ['../Data/ai/changed_dev.txt','../Data/ai/changed_dev.txt','../Data/ai/changed_dev.txt','../Data/ai/changed_dev.txt', '../Data/ai/changed_dev.txt', '../Data/ai/changed_dev.txt']
preds = ['../Predictions/random_10.txt', '../Predictions/random_20.txt', '../Predictions/random_30.txt', '../Predictions/random_40.txt', '../Predictions/random_50.txt', '../Predictions/random_60.txt']

scores = learning_curve(golds, preds)
plt.plot(size, scores, color="red",  label="Learning curve of baseline model")

# %%
import codecs

def read_data(file_name):
    """
    read in conll file
    
    :param file_name: path to read from
    :returns: list with sequences of words and labels for each sentence
    """
    data = []
    current_words = []
    current_tags = []

    for line in codecs.open(file_name, encoding='utf-8'):
        line = line.strip()

        if line:
            tok = line.split('\t')
            word = tok[0]
            tag = tok[1]

            current_words.append(word)
            current_tags.append(tag)

        else:
            if current_words:  # skip empty lines
                data.append((current_words, current_tags))
            current_words = []
            current_tags = []

    # check for last one
    if current_tags != []:
        data.append((current_words, current_tags))
    return data


def unite_lists(data):
    result = []
    for l in data:
        result += l
    return result

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import pandas as pd

# %%
ai = read_data("../Data/ai/changed_test.txt")
pred = read_data("../Entropy Scores/ai_baseline_dev_reannotated_test_pred.txt")

# %%
ground_truth= unite_lists(pd.DataFrame(ai)[1])
predicted = unite_lists(pd.DataFrame(pred)[1])

# %%
ground_truth= unite_lists(pd.DataFrame(ai)[1])
predicted = unite_lists(pd.DataFrame(pred)[1])
cm = confusion_matrix(ground_truth, predicted)

unique_labels = np.unique(ground_truth)
cm = confusion_matrix(ground_truth, predicted, labels=unique_labels)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=unique_labels, yticklabels=unique_labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
import matplotlib.pyplot as plt
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn import metrics
import itertools

score = metrics.accuracy_score(ground_truth, predicted)
print("accuracy:   %0.3f" % score)

# classes=['True', 'False']
classes =np.unique(ground_truth)
cm = metrics.confusion_matrix(ground_truth, predicted)
plot_confusion_matrix(cm, classes=classes)
# Out:
# accuracy:   0.823
# Confusion matrix, without normalization

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report

print('Micro Precision: {:.2f}'.format(precision_score(ground_truth, predicted, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(ground_truth, predicted, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(ground_truth, predicted, average='micro')))
# Out:
# Micro Precision: 0.82
# Micro Recall: 0.82
# Micro F1-score: 0.82

# %%
print('\nClassification Report\n')
print(classification_report(ground_truth, predicted))
# Out:
# Classification Report
#
#                 precision    recall  f1-score   support
#
#     B-location       0.71      0.60      0.65       166
#         B-misc       0.51      0.66      0.57      2466
# B-organisation       0.61      0.35      0.45       532
#       B-person       0.85      0.58      0.69       454
#     I-location       0.54      0.35      0.43       139
#         I-misc       0.63      0.59      0.61      2446
# I-organisation       0.62      0.66      0.64       927
#       I-person       0.87      0.72      0.79       404
#              O       0.92      0.91      0.92     18448
#
#       accuracy                           0.82     25982
#      macro avg       0.70      0.60      0.64     25982
#   weighted avg       0.83      0.82      0.82     25982
